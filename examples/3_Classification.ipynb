# %% [markdown]
# ##Fit a classifier on interesting sample labels.
# Learn important features for the classifier.

# %%
import css_styling
# Out:
# <link rel="stylesheet" href="http://bootswatch.com/paper/bootstrap.css">
# <style>.rendered_html {    font-size: 150%;}</style>

# %%
import flotilla

# %%
study = flotilla.embark("pag_demo")
# Out:
# 2015-01-10 17:05:01	Reading datapackage from /Users/lovci/flotilla_projects/pag_demo/datapackage.json
# 2015-01-10 17:05:01	Parsing datapackage to create a Study object
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-3-cead4d0c4951> in <module>()
# ----> 1 study = flotilla.embark("pag_demo")
#
# /Users/lovci/Projects/flotilla_dev/flotilla/__init__.pyc in embark(study_name, load_species_data)
#      43                                             study_name)))
#      44         return Study.from_datapackage_file(filename,
# ---> 45                                            load_species_data=load_species_data)
#      46     except IOError:
#      47         return Study.from_datapackage_url(study_name,
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/study.pyc in from_datapackage_file(cls, datapackage_filename, load_species_data, species_datapackage_base_url)
#     431             datapackage, datapackage_dir=datapackage_dir,
#     432             load_species_data=load_species_data,
# --> 433             species_datapackage_base_url=species_datapackage_base_url)
#     434
#     435     @staticmethod
#
# /Users/lovci/Projects/flotilla_dev/flotilla/data_model/study.pyc in from_datapackage(cls, datapackage, datapackage_dir, load_species_data, species_datapackage_base_url)
#     495
#     496             dfs[name] = reader(filename, compression=compression,
# --> 497                                header=header, index_col=index_col)
#     498
#     499             for key in set(resource.keys()).difference(
#
# /Users/lovci/Projects/flotilla_dev/flotilla/util.pyc in load_csv(file_name, **kwargs)
#     262
#     263 def load_csv(file_name, **kwargs):
# --> 264     return pd.read_csv(file_name, **kwargs)
#     265
#     266
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     418                     infer_datetime_format=infer_datetime_format)
#     419
# --> 420         return _read(filepath_or_buffer, kwds)
#     421
#     422     parser_f.__name__ = name
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     223         return parser
#     224
# --> 225     return parser.read()
#     226
#     227 _parser_defaults = {
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#     624                 raise ValueError('skip_footer not supported for iteration')
#     625
# --> 626         ret = self._engine.read(nrows)
#     627
#     628         if self.options.get('as_recarray'):
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1068
#    1069         try:
# -> 1070             data = self._reader.read(nrows)
#    1071         except StopIteration:
#    1072             if nrows is None:
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.read (pandas/parser.c:6866)()
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._read_low_memory (pandas/parser.c:7086)()
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._read_rows (pandas/parser.c:7691)()
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:7575)()
#
# /Users/lovci/venv/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.raise_parser_error (pandas/parser.c:19038)()
#
# CParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# ##Interactive classifier
# ###User can control:
#   * Sample and feature subsets used for classification<br><br>
#   * Categorical variable to classify<br><br>
#   * Parameter that selects a cutoff for feature importance from the classifier.<br><br>
#
# ###The interactive control widget looks like this:
#
# <img src="img/interactive_classifier_widgets.png" align='left'/>

# %% [markdown]
# ###Which protein-coding genes best discriminate cell-types?

# %%
study.interactive_classifier(feature_subsets=['gene_type: protein_coding'],
                             categorical_variables=['phenotype']);
# Out:
# savefile :
# predictor_type : ExtraTreesClassifier
# data_type : expression
# score_coefficient : 2.0
# sample_subset : all_samples
# feature_subset : gene_type: protein_coding
# categorical_variable : phenotype
# 2014-11-06 09:00:22 Configuring predictor type: ExtraTreesClassifier with 20345 features
# /Users/lovci/Projects/flotilla_dev/flotilla/compute/predict.py:528: UserWarning: WARNING: trait phenotype has >2 categories
#   self.trait_name))
# [Parallel(n_jobs=4)]: Done   1 out of   4 | elapsed:    3.4s remaining:   10.3s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.5s finished
# Fitting a predictor for X:all_samples_gene_type: protein_coding, y:phenotype, method:ExtraTreesClassifier... please wait.
# 	Finished.

# %% [markdown]
# ###Which RNA-binding proteins best discriminate cell-types?

# %%
study.interactive_classifier(feature_subsets=['confident_rbp'], 
                             categorical_variables=['phenotype']);
# Out:
# savefile :
# predictor_type : ExtraTreesClassifier
# data_type : expression
# score_coefficient : 2.0
# sample_subset : all_samples
# feature_subset : confident_rbp
# categorical_variable : phenotype
# 2014-11-06 09:00:46 Configuring predictor type: ExtraTreesClassifier with 458 features
# Fitting a predictor for X:all_samples_confident_rbp, y:phenotype, method:ExtraTreesClassifier... please wait.
# 	Finished.
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# /Users/lovci/venv/lib/python2.7/site-packages/sklearn/ensemble/forest.py:373: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "

# %% [markdown]
# ###Which genes respond to sodium arsenite stress in neurons?

# %%
#study.metadata.data['neuron_cell'] = study.metadata.merge_boolean_columns(['S_cell', 'M_cell'])
study.metadata.data['neuron_cell'] = ~study.metadata.merge_boolean_columns(['P_cell', 'N_cell', 'pooled_samples'])

# %%
study.interactive_classifier(feature_subsets=['gene_type: protein_coding'], 
                             categorical_variables=['phenotype'],
                             sample_subsets=['neuron_cell']);
# Out:
# savefile :
# predictor_type : ExtraTreesClassifier
# data_type : expression
# score_coefficient : 2.0
# sample_subset : neuron_cell
# feature_subset : gene_type: protein_coding
# categorical_variable : phenotype
# 2014-11-06 09:00:57 Configuring predictor type: ExtraTreesClassifier with 20345 features
# Fitting a predictor for X:neuron_cell_gene_type: protein_coding, y:phenotype, method:ExtraTreesClassifier... please wait.
# 	Finished.
# [Parallel(n_jobs=4)]: Done   1 out of   4 | elapsed:    1.0s remaining:    2.9s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    1.0s finished

# %% [markdown]
# ###Which splicing events discriminate cell types?

# %%
study.interactive_classifier(data_types=['splicing'], 
                             feature_subsets=['splice_type: SE'],
                             categorical_variables=['phenotype']);
# Out:
# savefile :
# predictor_type : ExtraTreesClassifier
# data_type : splicing
# score_coefficient : 2.0
# sample_subset : all_samples
# feature_subset : splice_type: SE
# categorical_variable : phenotype
# 2014-11-06 09:01:19 Configuring predictor type: ExtraTreesClassifier with 32539 features
# [Parallel(n_jobs=4)]: Done   1 out of   4 | elapsed:    8.9s remaining:   26.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    9.0s finished
# Fitting a predictor for X:all_samples_splice_type: SE, y:phenotype, method:ExtraTreesClassifier... please wait.
# 	Finished.

# %% [markdown]
# ##Summary
#
#   Users can learn which variables best discriminate categorical labels on their data.
